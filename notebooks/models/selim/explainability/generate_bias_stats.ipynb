# %%
import pandas as pd
from collections import defaultdict
from ast import literal_eval
from typing import List
import numpy as np
from sklearn.metrics import jaccard_score
import difflib

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### gender stats

# %%
def inter(a,b):
    
    c = []
    for num in a:
        if num in b and (not len(c) or b.index(c[-1]) < b.index(num)):
            c.append(num)
    return c

def jaccard_score_two_sentences(first_sentence: List[str], second_sentence: List[str]):
    len_sent_one = len(first_sentence)
    len_sent_two = len(second_sentence)
    if abs(len_sent_one - len_sent_two)>2:
        return 0
    else:
            
        set_first_sent = set(first_sentence)
        set_second_sent = set(second_sentence)
        intersection = len(inter(first_sentence, second_sentence))
        union = len(set(first_sentence).union(set(second_sentence)))
        return intersection / union

def custom_jaccard_score(input_sentence: List[str], sentences: List[List[str]]):
    sentences_len = len(sentences)
    scores_one_row = []
    for j in range(sentences_len):
        scores_one_row.append(jaccard_score_two_sentences(input_sentence, sentences[j]))

    return np.array(scores_one_row)

def rematch_df(df, n_items: int):
    # n_items = 3 if kwords are male, female, neutral etc.
    counts_df = (
        df.entry_id.value_counts()
        .to_frame()
        .reset_index()
        .rename(columns={"entry_id": "counts", "index": "entry_id"})
    )
    more_than_one_sentence_ids = counts_df[counts_df['counts'] > n_items].entry_id.tolist()

    only_one_sentence_ids = list(
        set(counts_df.entry_id.tolist()) - set(more_than_one_sentence_ids)
    )

    final_df = df[df.entry_id.isin(only_one_sentence_ids)].sort_values(by='entry_id')

    #kwords
    kwords_not_neutral = list(df['kw'].unique())
    kwords_not_neutral.remove('neutral')

    for one_id in more_than_one_sentence_ids:
        df_same_id = df[df.entry_id == one_id]

        neutral_df = df_same_id[df_same_id.kw=='neutral']

        for i in range(len(neutral_df)):
            one_row = neutral_df.iloc[[i]].copy()

            for one_kw in kwords_not_neutral:
                df_one_kw = df_same_id[df_same_id.kw==one_kw]

                similtarities = []

                split_original_excerpt: List[str] = one_row.excerpt.values[0].split(' ')
                split_excerpts: List[List[str]] = df_one_kw.excerpt.apply(lambda x: x.split(' ')).tolist()

                jaccard_scores = custom_jaccard_score(split_original_excerpt, split_excerpts)
                best_id = np.argmax(jaccard_scores)

                one_row = one_row.append(df_one_kw.iloc[[best_id]])

            final_df = final_df.append(one_row)

    return final_df

# %%
def get_gender(word):
    if 'person' in word:
        return 'neutral'
    elif any([one_female_kw in word for one_female_kw in ["women", "woman", "girl", "female", "mother"]]):
        return 'female'
    else:
        return 'male'

gender_results = pd.read_csv('final_data/gender_df_with_outputs.csv.gz', compression='gzip')

gender_results['kw'] = gender_results.kw.apply(get_gender)
# get proba shifts
probabilities_shifts = defaultdict(lambda: defaultdict(list))

gender_results["probability"] = gender_results["probability"].apply(literal_eval)

rematched_df = rematch_df(gender_results, n_items=gender_results['kw'].nunique())

# %%
n_items = 3
for i in range (0, rematched_df.shape[0], n_items):
    df_one_id = rematched_df[i: i + n_items]

    # get neutral proba
    neutral_proba = df_one_id[df_one_id.kw == "neutral"].probability.values[0]

    # get proba for each gender
    for one_gender in ["male", "female"]:
        probas_one_gender = df_one_id[df_one_id.kw == one_gender].probability.values[0]
        for tag, proba in probas_one_gender.items():
            probabilities_shifts[tag][one_gender].append(proba - neutral_proba[tag])

# %%
shifts_gender = defaultdict(lambda: defaultdict(float))

for tag, probas_per_gender in probabilities_shifts.items():
    
    for gender, probas_list in probas_per_gender.items():
        shifts_gender[tag][f"{gender}_mean"] = round(np.mean(probas_list), 2)
        shifts_gender[tag][f"{gender}_median"] =  round(np.median(probas_list), 2)
        shifts_gender[tag][f"{gender}_std"] =  round(np.std(probas_list), 2)


shifts_gender_df = pd.DataFrame.from_dict(shifts_gender, orient='index')
shifts_gender_df.index.name = 'tag'
shifts_gender_df
# Out:
#                                                     male_mean  male_median  \
# tag
# first_level_tags->pillars_1d->Casualties                -0.18        -0.00
# first_level_tags->pillars_1d->Context                    0.45         0.03
# first_level_tags->pillars_1d->Covid-19                  -0.22        -0.00
# first_level_tags->pillars_1d->Displacement              -0.65        -0.01
# first_level_tags->pillars_1d->Humanitarian Access       -0.13        -0.01
# ...                                                       ...          ...
# subpillars->Priority Needs->Expressed By Humani...      -0.32        -0.00
# subpillars->Priority Needs->Expressed By Popula...      -0.17        -0.00
# subpillars->Shock/Event->Hazard & Threats                0.16         0.00
# subpillars->Shock/Event->Type And Characteristics       -0.10        -0.00
# subpillars->Shock/Event->Underlying/Aggravating...      -0.06         0.00
#
#                                                     male_std  female_mean  \
# tag
# first_level_tags->pillars_1d->Casualties                2.61        -0.14
# first_level_tags->pillars_1d->Context                   5.23         1.54
# first_level_tags->pillars_1d->Covid-19                  2.30        -0.24
# first_level_tags->pillars_1d->Displacement              4.22        -0.49
# first_level_tags->pillars_1d->Humanitarian Access       0.84        -0.17
# ...                                                      ...          ...
# subpillars->Priority Needs->Expressed By Humani...      3.23        -0.44
# subpillars->Priority Needs->Expressed By Popula...      4.27        -0.07
# subpillars->Shock/Event->Hazard & Threats               2.01         0.12
# subpillars->Shock/Event->Type And Characteristics       1.23        -0.16
# subpillars->Shock/Event->Underlying/Aggravating...      0.68        -0.08
#
#                                                     female_median  female_std
# tag
# first_level_tags->pillars_1d->Casualties                    -0.00        3.14
# first_level_tags->pillars_1d->Context                        0.15        7.80
# first_level_tags->pillars_1d->Covid-19                      -0.00        3.89
# first_level_tags->pillars_1d->Displacement                  -0.01        5.59
# first_level_tags->pillars_1d->Humanitarian Access           -0.01        0.80
# ...                                                           ...         ...
# subpillars->Priority Needs->Expressed By Humani...          -0.00        3.30
# subpillars->Priority Needs->Expressed By Popula...          -0.00        3.98
# subpillars->Shock/Event->Hazard & Threats                    0.00        2.03
# subpillars->Shock/Event->Type And Characteristics           -0.00        1.33
# subpillars->Shock/Event->Underlying/Aggravating...          -0.00        0.86
#
# [75 rows x 6 columns]

# %%
treated_kwords = list(gender_results['kw'].unique())
treated_kwords.remove('neutral')

for one_kw in treated_kwords:
    shifts_gender_df[[
        f'{one_kw}_mean', f'{one_kw}_median', f'{one_kw}_std'
    ]].to_csv(f'results/second_results_golden_set/gender/shifts_{one_kw}.csv')

# %%
shifts_gender_df.sort_values(by='male_mean', ascending=False)
# Out:
#                                                     male_mean  male_median  \
# tag
# first_level_tags->pillars_2d->Impact                     2.28         0.23
# first_level_tags->sectors->Protection                    2.13         0.16
# subpillars->Impact->Impact On People                     1.96         0.08
# first_level_tags->sectors->Livelihoods                   0.89         0.03
# subpillars->Impact->Driver/Aggravating Factors           0.86         0.05
# ...                                                       ...          ...
# first_level_tags->sectors->Cross                        -0.62         0.01
# first_level_tags->pillars_1d->Displacement              -0.65        -0.01
# subpillars->Humanitarian Conditions->Physical A...      -0.77        -0.04
# subpillars->Humanitarian Conditions->Living Sta...      -1.57        -0.18
# first_level_tags->pillars_2d->Humanitarian Cond...      -1.74        -0.25
#
#                                                     male_std  female_mean  \
# tag
# first_level_tags->pillars_2d->Impact                    6.93         2.18
# first_level_tags->sectors->Protection                   8.67         5.04
# subpillars->Impact->Impact On People                    6.71         2.31
# first_level_tags->sectors->Livelihoods                  6.14         1.36
# subpillars->Impact->Driver/Aggravating Factors          3.10         0.96
# ...                                                      ...          ...
# first_level_tags->sectors->Cross                        6.71        -1.50
# first_level_tags->pillars_1d->Displacement              4.22        -0.49
# subpillars->Humanitarian Conditions->Physical A...      5.31        -0.77
# subpillars->Humanitarian Conditions->Living Sta...      5.87        -1.67
# first_level_tags->pillars_2d->Humanitarian Cond...      7.18        -2.29
#
#                                                     female_median  female_std
# tag
# first_level_tags->pillars_2d->Impact                         0.15        7.47
# first_level_tags->sectors->Protection                        0.74       11.50
# subpillars->Impact->Impact On People                         0.09        7.75
# first_level_tags->sectors->Livelihoods                       0.03        7.02
# subpillars->Impact->Driver/Aggravating Factors               0.05        3.70
# ...                                                           ...         ...
# first_level_tags->sectors->Cross                            -0.06        7.57
# first_level_tags->pillars_1d->Displacement                  -0.01        5.59
# subpillars->Humanitarian Conditions->Physical A...          -0.03        7.07
# subpillars->Humanitarian Conditions->Living Sta...          -0.21        6.79
# first_level_tags->pillars_2d->Humanitarian Cond...          -0.32        9.38
#
# [75 rows x 6 columns]

# %% [markdown]
# ## minorities stats

# %%
minorities_results = pd.read_csv('final_data/minorities_df_with_outputs.csv.gz', compression='gzip')

minorities_results['kw'] = minorities_results['kw'].apply(
    lambda x: x if x!='person' else 'neutral'
)

# get proba shifts
probabilities_shifts = defaultdict(lambda: defaultdict(list))

minorities_results["probability"] = minorities_results["probability"].apply(literal_eval)

rematched_minorities_df = rematch_df(minorities_results, n_items=minorities_results['kw'].nunique())

# %%
rematched_minorities_df.shape, minorities_results.shape
# Out:
# ((294, 5), (294, 5))

# %%
rematched_minorities_df
# Out:
#                                                excerpt  entry_id  \
# 293  They indicated that the level of tolerance tow...   57176.0
# 281  They indicated that the level of tolerance tow...   57176.0
# 20   They indicated that the level of tolerance tow...   57176.0
# 282  They indicated that the level of tolerance tow...   57176.0
# 283  They indicated that the level of tolerance tow...   57176.0
# ..                                                 ...       ...
# 119  For example, there has been no specific focus ...   65071.0
# 120  For example, there has been no specific focus ...   65071.0
# 121  For example, there has been no specific focus ...   65071.0
# 122  For example, there has been no specific focus ...   65071.0
# 123  For example, there has been no specific focus ...   65071.0
#
#                               kw       type  \
# 293                      neutral  augmented
# 281                  transgender  augmented
# 20                          lgbt   original
# 282                   sex worker  augmented
# 283                   homosexual  augmented
# ..                           ...        ...
# 119                      refugee  augmented
# 120                      migrant  augmented
# 121                asylum seeker  augmented
# 122                          IDP  augmented
# 123  internally displaced people  augmented
#
#                                            probability
# 293  {'first_level_tags->pillars_1d->Casualties': 0...
# 281  {'first_level_tags->pillars_1d->Casualties': 0...
# 20   {'first_level_tags->pillars_1d->Casualties': 0...
# 282  {'first_level_tags->pillars_1d->Casualties': 0...
# 283  {'first_level_tags->pillars_1d->Casualties': 0...
# ..                                                 ...
# 119  {'first_level_tags->pillars_1d->Casualties': 0...
# 120  {'first_level_tags->pillars_1d->Casualties': 0...
# 121  {'first_level_tags->pillars_1d->Casualties': 0...
# 122  {'first_level_tags->pillars_1d->Casualties': 0...
# 123  {'first_level_tags->pillars_1d->Casualties': 0...
#
# [294 rows x 5 columns]

# %%
minorities_kwords = list(minorities_results['kw'].unique())
minorities_kwords.remove('neutral')
len(minorities_kwords)
# Out:
# 13

# %%
n_items = len(minorities_results.kw.unique())
for i in range (0, rematched_minorities_df.shape[0], n_items):
    df_one_id = rematched_minorities_df[i: i + n_items]

    # get neutral proba
    neutral_proba = df_one_id[df_one_id.kw == "neutral"].probability.values[0]

    # get proba for each gender
    for one_gender in minorities_kwords:
        probas_one_gender = df_one_id[df_one_id.kw == one_gender].probability.values[0]
        for tag, proba in probas_one_gender.items():
            probabilities_shifts[tag][one_gender].append(proba - neutral_proba[tag])

# %%
shifts_minorities = defaultdict(lambda: defaultdict(float))

for tag, probas_per_minority in probabilities_shifts.items():
    for one_pop, probas_list in probas_per_minority.items():
        shifts_minorities[tag][f"{one_pop}_mean"] = round(np.mean(probas_list), 2)
        shifts_minorities[tag][f"{one_pop}_median"] =  round(np.median(probas_list), 2)
        shifts_minorities[tag][f"{one_pop}_std"] =  round(np.std(probas_list), 2)

shifts_minorities_df = pd.DataFrame.from_dict(shifts_minorities, orient='index')
#shifts_minorities_df.to_csv('shifts_minorities.csv')
shifts_minorities_df
# Out:
#                                                     sex worker_mean  \
# first_level_tags->pillars_1d->Casualties                      -0.56
# first_level_tags->pillars_1d->Context                         -5.56
# first_level_tags->pillars_1d->Covid-19                        -0.38
# first_level_tags->pillars_1d->Displacement                    -1.83
# first_level_tags->pillars_1d->Humanitarian Access             -0.12
# ...                                                             ...
# subpillars->Priority Needs->Expressed By Humani...            -0.23
# subpillars->Priority Needs->Expressed By Popula...            -0.70
# subpillars->Shock/Event->Hazard & Threats                     -0.17
# subpillars->Shock/Event->Type And Characteristics             -0.17
# subpillars->Shock/Event->Underlying/Aggravating...            -0.48
#
#                                                     sex worker_median  \
# first_level_tags->pillars_1d->Casualties                        -0.00
# first_level_tags->pillars_1d->Context                           -0.34
# first_level_tags->pillars_1d->Covid-19                          -0.00
# first_level_tags->pillars_1d->Displacement                      -0.18
# first_level_tags->pillars_1d->Humanitarian Access               -0.02
# ...                                                               ...
# subpillars->Priority Needs->Expressed By Humani...               0.00
# subpillars->Priority Needs->Expressed By Popula...              -0.01
# subpillars->Shock/Event->Hazard & Threats                       -0.06
# subpillars->Shock/Event->Type And Characteristics               -0.04
# subpillars->Shock/Event->Underlying/Aggravating...              -0.05
#
#                                                     sex worker_std  lgbt_mean  \
# first_level_tags->pillars_1d->Casualties                      2.38       0.76
# first_level_tags->pillars_1d->Context                        13.54      -2.22
# first_level_tags->pillars_1d->Covid-19                        1.15      -0.46
# first_level_tags->pillars_1d->Displacement                    6.49      -0.29
# first_level_tags->pillars_1d->Humanitarian Access             0.43      -0.08
# ...                                                            ...        ...
# subpillars->Priority Needs->Expressed By Humani...            1.54       0.66
# subpillars->Priority Needs->Expressed By Popula...            2.32      -0.40
# subpillars->Shock/Event->Hazard & Threats                     0.59       0.08
# subpillars->Shock/Event->Type And Characteristics             0.22      -0.05
# subpillars->Shock/Event->Underlying/Aggravating...            1.19       0.26
#
#                                                     lgbt_median  lgbt_std  \
# first_level_tags->pillars_1d->Casualties                   0.00      3.38
# first_level_tags->pillars_1d->Context                     -0.34      4.03
# first_level_tags->pillars_1d->Covid-19                    -0.01      1.24
# first_level_tags->pillars_1d->Displacement                 0.00      5.88
# first_level_tags->pillars_1d->Humanitarian Access          0.00      0.28
# ...                                                         ...       ...
# subpillars->Priority Needs->Expressed By Humani...         0.01      3.07
# subpillars->Priority Needs->Expressed By Popula...         0.00      1.34
# subpillars->Shock/Event->Hazard & Threats                  0.00      0.72
# subpillars->Shock/Event->Type And Characteristics         -0.02      0.22
# subpillars->Shock/Event->Underlying/Aggravating...         0.02      1.20
#
#                                                     transgender_mean  \
# first_level_tags->pillars_1d->Casualties                        0.20
# first_level_tags->pillars_1d->Context                          -2.13
# first_level_tags->pillars_1d->Covid-19                         -0.33
# first_level_tags->pillars_1d->Displacement                      4.71
# first_level_tags->pillars_1d->Humanitarian Access               0.00
# ...                                                              ...
# subpillars->Priority Needs->Expressed By Humani...              0.68
# subpillars->Priority Needs->Expressed By Popula...             -0.51
# subpillars->Shock/Event->Hazard & Threats                      -0.02
# subpillars->Shock/Event->Type And Characteristics              -0.02
# subpillars->Shock/Event->Underlying/Aggravating...              0.12
#
#                                                     transgender_median  \
# first_level_tags->pillars_1d->Casualties                         -0.00
# first_level_tags->pillars_1d->Context                            -0.24
# first_level_tags->pillars_1d->Covid-19                            0.00
# first_level_tags->pillars_1d->Displacement                        0.11
# first_level_tags->pillars_1d->Humanitarian Access                -0.00
# ...                                                                ...
# subpillars->Priority Needs->Expressed By Humani...                0.02
# subpillars->Priority Needs->Expressed By Popula...                0.00
# subpillars->Shock/Event->Hazard & Threats                        -0.07
# subpillars->Shock/Event->Type And Characteristics                -0.00
# subpillars->Shock/Event->Underlying/Aggravating...               -0.01
#
#                                                     transgender_std  \
# first_level_tags->pillars_1d->Casualties                       1.00
# first_level_tags->pillars_1d->Context                          5.62
# first_level_tags->pillars_1d->Covid-19                         1.01
# first_level_tags->pillars_1d->Displacement                     9.45
# first_level_tags->pillars_1d->Humanitarian Access              0.05
# ...                                                             ...
# subpillars->Priority Needs->Expressed By Humani...             2.23
# subpillars->Priority Needs->Expressed By Popula...             1.48
# subpillars->Shock/Event->Hazard & Threats                      0.41
# subpillars->Shock/Event->Type And Characteristics              0.24
# subpillars->Shock/Event->Underlying/Aggravating...             0.65
#
#                                                     homosexual_mean  ...  \
# first_level_tags->pillars_1d->Casualties                      -0.48  ...
# first_level_tags->pillars_1d->Context                         -0.71  ...
# first_level_tags->pillars_1d->Covid-19                        -0.43  ...
# first_level_tags->pillars_1d->Displacement                    -0.57  ...
# first_level_tags->pillars_1d->Humanitarian Access             -0.05  ...
# ...                                                             ...  ...
# subpillars->Priority Needs->Expressed By Humani...             0.35  ...
# subpillars->Priority Needs->Expressed By Popula...            -0.56  ...
# subpillars->Shock/Event->Hazard & Threats                      0.08  ...
# subpillars->Shock/Event->Type And Characteristics              0.04  ...
# subpillars->Shock/Event->Underlying/Aggravating...             0.36  ...
#
#                                                     migrant_std  \
# first_level_tags->pillars_1d->Casualties                   0.56
# first_level_tags->pillars_1d->Context                      5.51
# first_level_tags->pillars_1d->Covid-19                     1.25
# first_level_tags->pillars_1d->Displacement                 8.42
# first_level_tags->pillars_1d->Humanitarian Access          0.46
# ...                                                         ...
# subpillars->Priority Needs->Expressed By Humani...         1.00
# subpillars->Priority Needs->Expressed By Popula...         1.54
# subpillars->Shock/Event->Hazard & Threats                  0.41
# subpillars->Shock/Event->Type And Characteristics          0.28
# subpillars->Shock/Event->Underlying/Aggravating...         0.77
#
#                                                     asylum seeker_mean  \
# first_level_tags->pillars_1d->Casualties                          0.54
# first_level_tags->pillars_1d->Context                             2.31
# first_level_tags->pillars_1d->Covid-19                           -0.17
# first_level_tags->pillars_1d->Displacement                        1.85
# first_level_tags->pillars_1d->Humanitarian Access                -0.03
# ...                                                                ...
# subpillars->Priority Needs->Expressed By Humani...               -0.16
# subpillars->Priority Needs->Expressed By Popula...               -0.76
# subpillars->Shock/Event->Hazard & Threats                         0.07
# subpillars->Shock/Event->Type And Characteristics                 0.08
# subpillars->Shock/Event->Underlying/Aggravating...                1.26
#
#                                                     asylum seeker_median  \
# first_level_tags->pillars_1d->Casualties                           -0.00
# first_level_tags->pillars_1d->Context                               0.49
# first_level_tags->pillars_1d->Covid-19                              0.00
# first_level_tags->pillars_1d->Displacement                          0.07
# first_level_tags->pillars_1d->Humanitarian Access                   0.00
# ...                                                                  ...
# subpillars->Priority Needs->Expressed By Humani...                 -0.00
# subpillars->Priority Needs->Expressed By Popula...                 -0.00
# subpillars->Shock/Event->Hazard & Threats                           0.02
# subpillars->Shock/Event->Type And Characteristics                   0.00
# subpillars->Shock/Event->Underlying/Aggravating...                  0.28
#
#                                                     asylum seeker_std  \
# first_level_tags->pillars_1d->Casualties                         2.44
# first_level_tags->pillars_1d->Context                            3.95
# first_level_tags->pillars_1d->Covid-19                           0.92
# first_level_tags->pillars_1d->Displacement                       9.45
# first_level_tags->pillars_1d->Humanitarian Access                0.45
# ...                                                               ...
# subpillars->Priority Needs->Expressed By Humani...               1.06
# subpillars->Priority Needs->Expressed By Popula...               2.33
# subpillars->Shock/Event->Hazard & Threats                        0.57
# subpillars->Shock/Event->Type And Characteristics                0.36
# subpillars->Shock/Event->Underlying/Aggravating...               4.03
#
#                                                     IDP_mean  IDP_median  \
# first_level_tags->pillars_1d->Casualties               -0.52       -0.00
# first_level_tags->pillars_1d->Context                  -0.62        0.31
# first_level_tags->pillars_1d->Covid-19                 -0.26       -0.00
# first_level_tags->pillars_1d->Displacement              1.09       -0.02
# first_level_tags->pillars_1d->Humanitarian Access      -0.00       -0.01
# ...                                                      ...         ...
# subpillars->Priority Needs->Expressed By Humani...     -0.29       -0.01
# subpillars->Priority Needs->Expressed By Popula...     -0.88       -0.01
# subpillars->Shock/Event->Hazard & Threats               0.09        0.03
# subpillars->Shock/Event->Type And Characteristics       0.05        0.00
# subpillars->Shock/Event->Underlying/Aggravating...      0.16        0.01
#
#                                                     IDP_std  \
# first_level_tags->pillars_1d->Casualties               2.16
# first_level_tags->pillars_1d->Context                  3.55
# first_level_tags->pillars_1d->Covid-19                 0.90
# first_level_tags->pillars_1d->Displacement             9.33
# first_level_tags->pillars_1d->Humanitarian Access      0.27
# ...                                                     ...
# subpillars->Priority Needs->Expressed By Humani...     1.33
# subpillars->Priority Needs->Expressed By Popula...     2.93
# subpillars->Shock/Event->Hazard & Threats              0.41
# subpillars->Shock/Event->Type And Characteristics      0.43
# subpillars->Shock/Event->Underlying/Aggravating...     0.67
#
#                                                     internally displaced people_mean  \
# first_level_tags->pillars_1d->Casualties                                       -0.23
# first_level_tags->pillars_1d->Context                                           1.14
# first_level_tags->pillars_1d->Covid-19                                         -0.37
# first_level_tags->pillars_1d->Displacement                                      2.99
# first_level_tags->pillars_1d->Humanitarian Access                               0.05
# ...                                                                              ...
# subpillars->Priority Needs->Expressed By Humani...                              0.26
# subpillars->Priority Needs->Expressed By Popula...                             -0.54
# subpillars->Shock/Event->Hazard & Threats                                       0.28
# subpillars->Shock/Event->Type And Characteristics                               0.06
# subpillars->Shock/Event->Underlying/Aggravating...                              0.19
#
#                                                     internally displaced people_median  \
# first_level_tags->pillars_1d->Casualties                                         -0.00
# first_level_tags->pillars_1d->Context                                             0.48
# first_level_tags->pillars_1d->Covid-19                                           -0.00
# first_level_tags->pillars_1d->Displacement                                        0.51
# first_level_tags->pillars_1d->Humanitarian Access                                 0.00
# ...                                                                                ...
# subpillars->Priority Needs->Expressed By Humani...                               -0.01
# subpillars->Priority Needs->Expressed By Popula...                               -0.00
# subpillars->Shock/Event->Hazard & Threats                                         0.09
# subpillars->Shock/Event->Type And Characteristics                                 0.02
# subpillars->Shock/Event->Underlying/Aggravating...                                0.05
#
#                                                     internally displaced people_std
# first_level_tags->pillars_1d->Casualties                                       0.89
# first_level_tags->pillars_1d->Context                                          3.73
# first_level_tags->pillars_1d->Covid-19                                         1.22
# first_level_tags->pillars_1d->Displacement                                     6.35
# first_level_tags->pillars_1d->Humanitarian Access                              0.16
# ...                                                                             ...
# subpillars->Priority Needs->Expressed By Humani...                             1.23
# subpillars->Priority Needs->Expressed By Popula...                             1.25
# subpillars->Shock/Event->Hazard & Threats                                      0.43
# subpillars->Shock/Event->Type And Characteristics                              0.19
# subpillars->Shock/Event->Underlying/Aggravating...                             0.52
#
# [75 rows x 39 columns]

# %%
for one_kw in minorities_kwords:
    shifts_minorities_df[[
        f'{one_kw}_mean', f'{one_kw}_median', f'{one_kw}_std'
    ]].to_csv(f'results/second_results_golden_set/minorities/shifts_{one_kw}.csv')

# %%
minorities_kwords
# Out:
# ['sex worker',
#  'lgbt',
#  'transgender',
#  'homosexual',
#  'lesbian',
#  'bisexual',
#  'intersexual',
#  'queer',
#  'refugee',
#  'migrant',
#  'asylum seeker',
#  'IDP',
#  'internally displaced people']
