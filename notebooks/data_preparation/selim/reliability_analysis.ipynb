# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1) Merge, preprocess files:

# %%
organizations = pd.read_csv('data_secondary_tags/reliability/organization_organization.csv')
organizations.head(2)
# Out:
#      id                 title      short_name             long_name  logo_id  \
# 0  6123                  ncdc            ncdc                  ncdc      NaN
# 1     4  Terre Solidali Onlus  Terre Solidali  Terre Solidali Onlus      NaN
#
#    organization_type_id                            url  \
# 0                   NaN                            NaN
# 1                   NaN  http://www.terresolidali.org/
#
#                       created_at  created_by_id  \
# 0  2020-03-02 08:17:34.823758+00            NaN
# 1  2019-04-29 17:58:56.821129+00            NaN
#
#                      modified_at  modified_by_id  verified  parent_id  \
# 0  2020-03-02 08:17:34.823785+00             NaN     False        NaN
# 1  2019-04-29 17:58:57.044937+00             NaN      True        NaN
#
#    relief_web_id
# 0            NaN
# 1            NaN

# %%
data_source = pd.read_csv('data_secondary_tags/reliability/leads.csv')
#sorted(data_source.source_id.unique())

# %%
data_source[data_source.source_id==2]
# Out:
#          id                     created_at                    modified_at  \
# 9758  45614  2020-12-15 18:58:42.861631+00  2021-04-15 20:28:20.112782+00
#
#                                                   title source_raw  \
# 9758  COVID-19 and Disruptions to Vulnerable Rural L...        NaN
#
#      confidentiality     status published_on text  \
# 9758     unprotected  validated   2020-08-01  NaN
#
#                                                     url  ... modified_by_id  \
# 9758  https://www.cgap.org/sites/default/files/publi...  ...           3009
#
#       project_id  attachment_id  source_type  lead_group_id client_id  \
# 9758        2333            NaN      website            NaN       NaN
#
#       author_raw  author_id source_id  priority
# 9758         NaN        NaN       2.0       100
#
# [1 rows x 22 columns]

# %%
pd.merge(
    organizations[['id','short_name', 'long_name']].rename(columns={'id':'source_id'}),
    data_source,
    how='outer',
    on='source_id',
).to_csv('data_secondary_tags/reliability/data_verification.csv')

# %%
data_source = pd.read_csv('data_secondary_tags/reliability/data_verification.csv',index_col=0)\
                    .drop(columns=['created_at',
                                   'modified_at',
                                   'confidentiality',
                                   'status',
                                   'published_on',
                                   'text',
                                   'created_by_id',
                                   'modified_by_id',
                                   'priority',
                                   'client_id',
                                   'author_id',
                                   'attachment_id',
                                   'project_id',
                                   'url'])

data_reliability = pd.read_csv('data_secondary_tags/reliability/reliabillity_tags.csv')\
                    .drop(columns=['Unnamed: 0',
                                    'Unnamed: 0.1',
                                   'analysis_framework_id',
                                   'project_id',
                                   'title',
                                   'exportable_id'])

# %%
merged_reliability = pd.merge(
                        data_reliability,
                        data_source,
                        how="outer",
                        left_on='lead_id',
                        right_on='id').drop(columns=['id',
                                                     'title',
                                                     'excerpt'])

# %%
merged_reliability.shape
# Out:
# (148890, 11)

# %%
merged_reliability.head(2)
# Out:
#    lead_id  entry_id         tag_value  source_id short_name long_name  \
# 0  10607.0   25639.0  Usually reliable        NaN        NaN       NaN
# 1  10607.0   25691.0  Usually reliable        NaN        NaN       NaN
#
#   source_raw        website source_type  lead_group_id author_raw
# 0  reliefweb  reliefweb.int     website            NaN        NaN
# 1  reliefweb  reliefweb.int     website            NaN        NaN

# %% [markdown]
# * Organisations have long and short name, sometimes one only
# * Create one column `name` to merge short and long names
# * Create one columns `postprocessed_name` to postprocess `name` column: when `name` column only has long or short name, add the missing name

# %%
def get_full_name (row):
    """
    Get full name, using short name, long name of organizations df
    """
    short_str = row.short_name
    long_str = row.long_name
    
    bool_short_name = pd.isna(short_str)
    bool_long_name = pd.isna(long_str)
    
    if bool_short_name and bool_long_name:
        return np.nan
    if bool_long_name:
        return short_str
    if bool_short_name:
        return long_str
    if short_str.upper() in long_str.upper():
        return long_str
    return row.short_name + ' / ' + row.long_name

# %%
merged_reliability['name'] = merged_reliability.apply(lambda x: get_full_name(x), axis=1)

# %%
bool_two_items = merged_reliability['name'].apply(lambda x: len(str(x).split('/'))>1 )
list_two_items = merged_reliability[bool_two_items].name.unique()

# %%
def post_process_names (row, list_tow_items=list_two_items):
    """
    if there is only short name or long name -> get full name (long and short names)
    """
    if pd.isna(row) :
        return row
    
    if len(str(row).split('/'))<2:
        for nam in list_tow_items:
            if str(row).upper() in ''.join(nam.split(' ')).upper():
                return nam
    return row

# %%
merged_reliability['postprocessed_name'] = merged_reliability.name.apply(lambda x: post_process_names(x))

# %%
merged_reliability = merged_reliability.drop(columns=['short_name', 'long_name'])

# %%
merged_reliability = merged_reliability[~merged_reliability.tag_value.isna()]\
                            .drop(columns=['lead_id', 'source_id', 'name'])

# %%
merged_reliability.head(2)
# Out:
#    entry_id         tag_value source_raw        website source_type  \
# 0   25639.0  Usually reliable  reliefweb  reliefweb.int     website
# 1   25691.0  Usually reliable  reliefweb  reliefweb.int     website
#
#    lead_group_id author_raw postprocessed_name
# 0            NaN        NaN                NaN
# 1            NaN        NaN                NaN

# %%
htps_data = merged_reliability[merged_reliability.website.str.contains('/'.upper(), na=False)]

# %% [markdown]
# ## 2) Website data:
# * I chose to omit the website `reliefweb` because it contains many different sources, it is not a source itself

# %%
def omit_https(url:str)->str:
    return url.split('/')[-1]

def extract_core_name (name:str)->str:
    """
    Extract core name from website url
    """
    split_list = name.split('.')
    
    if len(split_list)<=2:
        return omit_https(split_list[0])
    if split_list[1]=='com':
        return omit_https(split_list[0])
    else:
        return split_list[1]

# %%
website_data = merged_reliability[merged_reliability.source_type=='website']\
                    .drop(columns=['source_type', 'lead_group_id'])\
                    
website_data = website_data[(~website_data.website.isna()) & \
                            (website_data.website.apply(lambda x: 'reliefweb' not in x))]

website_data['core_name'] = website_data.website.apply(lambda x: extract_core_name(x))
website_data.head()
# Out:
#      entry_id         tag_value source_raw  \
# 21   102051.0  Usually reliable        NaN
# 22   102050.0  Usually reliable        NaN
# 23   102052.0  Usually reliable        NaN
# 24   102053.0  Usually reliable        NaN
# 272   96087.0  Usually reliable        NaN
#
#                                                website author_raw  \
# 21   https://www.dailysabah.com/turkey/turkey-repor...        NaN
# 22   https://www.dailysabah.com/turkey/turkey-repor...        NaN
# 23   https://www.dailysabah.com/turkey/turkey-repor...        NaN
# 24   https://www.dailysabah.com/turkey/turkey-repor...        NaN
# 272                               displacement.iom.int        NaN
#
#                                  postprocessed_name   core_name
# 21                                 DS / Daily Sabah  dailysabah
# 22                                 DS / Daily Sabah  dailysabah
# 23                                 DS / Daily Sabah  dailysabah
# 24                                 DS / Daily Sabah  dailysabah
# 272  IOM / International Organization for Migration         iom

# %%
tmp_df = website_data[['core_name', 'postprocessed_name']].dropna()\
        .groupby(['core_name'])['postprocessed_name'].agg(pd.Series.mode).to_frame().reset_index()

# %%
website_to_name_dict = dict(zip(tmp_df.core_name, tmp_df.postprocessed_name))

# %%
website_to_name_dict
# Out:
# {'1lockers': '1lockers',
#  '2001': '2001 Live',
#  '237actu': '237actu',
#  '7sur7': '7sur7',
#  'El espectador': 'El Espectador',
#  'FUPAD': 'FUPAD / Fundación Panamericana para el Desarrollo -Colombia',
#  'UNFPA': 'UNFPA / United Nations Population Fund',
#  'WHO': 'WHO / World Health Organization',
#  'aa': 'AA / Andalou Agency',
#  'aawsat': 'Asharq Al-Awsat',
#  'abc': 'ABC / Australian Broadcasting Corporation',
#  'acaps': 'ACAPS / Assessment Capacities Project',
#  'acento': 'acento',
#  'acleddata': 'acleddata',
#  'acnur': 'UNHCR / United Nations High Commissioner for Refugees',
#  'acpcongo': 'acpcongo',
#  'actalliance': 'DIAL / Digital Impact Alliance',
#  'acted': 'ACTED / Agency for Technical Cooperation and Development',
#  'actionagainsthunger': 'ACF / Action Against Hunger',
#  'actu24': 'actu24',
#  'actu30': 'actu30',
#  'actualite': 'Actualite.cd',
#  'acturdc': array(['Actu RDC', 'acturdc'], dtype=object),
#  'acu-sy': 'ACU / \u200eAssistance Coordination Unit',
#  'adiac-congo': 'adiac-congo',
#  'afdb': 'AfDB / African Development Bank',
#  'afghanistan-analysts': 'afghanistan-analysts',
#  'afia-amanigrandslacs': 'afia-amanigrandslacs',
#  'africa-newsroom': 'africa-newsroom',
#  'africacdc': 'Africa CDC / Africa Centres for Disease Control and Prevention',
#  'africanews': 'ANS / Africa News Service',
#  'afrik': 'IA / ImagiNation Afrika',
#  'afrique7': 'afrique7',
#  'afriquinfos': 'afriquinfos',
#  'afro': 'WHO / World Health Organization',
#  'agenceecofin': 'agenceecofin',
#  'agronet': 'Government of Colombia',
#  'aidfdouaniers': 'aidfdouaniers',
#  'al-monitor': 'Al Monitor',
#  'alaraby': 'Al-Araby',
#  'albaathmedia': 'albaathmedia',
#  'aleteia': 'Aleteia',
#  'alianzaporlasolidaridad': 'Alianza por la solidaridad',
#  'alima': 'ALIMA',
#  'alima-ngo': 'ALIMA',
#  'aljazeera': 'AJ / Aljazeera',
#  'alkhabar-sy': 'Al-Khabar / alkhabar-sy',
#  'alkhaleejtoday': 'Al Khaleej Today',
#  'allafrica': 'AllAfrica',
#  'allodocteurs': 'allodocteurs',
#  'alnap': 'ALNAP / Active Learning Network for Accountability and Performance in Humanitarian Action',
#  'alwatan': 'alwatan',
#  'alwatanonline': 'alwatanonline',
#  'alwehda': 'alwehda',
#  'amazonaws': 'Migravenezuela / Proyecto Migración Venezuela',
#  'ambafrance': "MEAE (France) / Ministère de l'Europe et des Affaires étrangères (France)",
#  'ambito': 'Ámbito',
#  'amd': 'TYF / Tamdeen Youth Foundation',
#  'americasquarterly': 'Americas Quarterly',
#  'amnesty': 'Amnesty International',
#  'analitica': 'Analitica',
#  'anfenglish': 'ANF News',
#  'aninews': 'aninews',
#  'apnews': 'apnews',
#  'aporrea': 'Aporrea',
#  'arabnews': 'arabnews / Arab News',
#  'areacucuta': 'areacucuta',
#  'areion24': 'areion24',
#  'as': 'Diario As Colombia',
#  'athrpress': 'athrpress',
#  'atlanticcouncil': 'The Atlantic Council / Atlantic Council',
#  'au': 'AU / African Union',
#  'authorityngr': 'authorityngr',
#  'bahamas': 'Govt. Bahamas',
#  'balkaninsight': 'ABC Color',
#  'bancomundial': 'GRUPO BANCO MUNDIAL',
#  'banquemondiale': 'banquemondiale',
#  'banrep': 'banrep / Banco de la República',
#  'bbc': 'BBC / British Broadcasting Corporation',
#  'bbvaresearch': 'BBVA',
#  'bdnews24': 'bdnews24',
#  'bhrt': 'bhrt',
#  'biscani': 'biscani',
#  'bles': 'Bles Mundo',
#  'bmj': 'BMJ / British Medical Journal',
#  'borgenmagazine': 'borgenmagazine',
#  'bpb': 'bpb',
#  'brac': 'BRAC / Bangladesh Rural Advancement Committee',
#  'britic': 'britic',
#  'brookings': 'brookings',
#  'btimesonline': 'btimesonline',
#  'burkina24': 'Burkina24',
#  'businessinsider': 'businessinsider / Business Insider',
#  'calpnetwork': 'ANALP / Active Learning Network for Accountability and Performance in Humanitarian Action',
#  'cambridge': 'Univ. of Cambridge',
#  'campaign-archive': 'cmr-covid19',
#  'canadianinquirer': 'canadianinquirer',
#  'canal1': 'Canal 1',
#  'canalrcn': 'canalrcn',
#  'cancilleria': array(['Government of Colombia', 'cancilleria'], dtype=object),
#  'caracol': 'caracol',
#  'caracoltv': 'caracoltv',
#  'care-international': 'care-international',
#  'careevaluations': 'careevaluations',
#  'caritas': 'Caritas Germany',
#  'caritasvenezuela': 'Caritas Venezuela',
#  'cbc': 'CBC',
#  'cepal': 'cepal',
#  'cfr': 'CFR / Council on Foreign Relations',
#  'cgap': 'CGAP',
#  'cgdev': 'RI / Refugees International',
#  'cgpolicy': 'Center for Global Policy',
#  'cgtn': 'cgtn',
#  'chamtimes': 'chamtimes',
#  'channelstv': 'channelstv',
#  'china': 'scmp / South China Morning Post',
#  'cia': 'CIA / Central Intelligence Agency',
#  'cippec': 'CIPPEC / Centro de Implementación de Políticas Públicas para la Equidad y el Crecimiento',
#  'clarin': 'Clarín',
#  'clingendael': "Netherlands Institute of International Relations 'Clingendael'",
#  'clovekvtisni': 'PIN / People in Need Foundation',
#  'cnews': 'IRNA / Islamic Republic News Agency',
#  'cnn': 'CNN / Cable News Network',
#  'co': 'Newsday',
#  'coar-global': 'COAR',
#  'colombia': 'Colombia.Com',
#  'colombiano24': 'colombiano24',
#  'columbia': 'UBC / University of British Columbia',
#  'comesa': 'COMESA',
#  'conciudadania': 'Con Ciudadanía',
#  'conexioncapital': 'Conexión Capital',
#  'congoactu': 'congoactu',
#  'congodurable': 'congodurable',
#  'congoindependant': 'congoindependant',
#  'congosynthese': 'congosynthese',
#  'congovirtuel': 'congovirtuel',
#  'connectnigeria': 'connectnigeria',
#  'cooperativa': 'Radio Cooperativa',
#  'cordaid': 'Cordaid',
#  'courrierinternational': 'courrierinternational',
#  'crhoy': 'CR hoy.Com',
#  'criptonoticias': 'Cripto Noticias',
#  'crisisgroup': 'ICG / International Crisis Group',
#  'cronica': 'Crónica',
#  'cronista': 'El Cronista',
#  'csis': 'CSIS / Center for Strategic and International Studies',
#  'csmonitor': 'CSMonitor / The Christian Science Monitor',
#  'dabangasudan': 'dabangasudan',
#  'dailymail': 'MO / Mail Online',
#  'dailypost': 'dailypost',
#  'dailysabah': 'DS / Daily Sabah',
#  'damascusv': 'Damascus v / Sawt al-Asimah',
#  'dane': 'DANE / Departamento Administrativo Nacional de Estadística',
#  'daraamartyrs': 'daraamartyrs / Daraa Martyrs',
#  'daraj': 'Daraj',
#  'debate': 'Debate',
#  'defense': 'NDIC / National Defense Intelligence College',
#  'defensoria': 'Defensoría del Pueblo Colombia',
#  'delawarepublic': 'Delaware Public Media',
#  'derechos': 'PROVEA / Programa Venezolano de Educación - Acción en Derechos Humanos',
#  'deskeco': 'deskeco',
#  'devex': 'Devex News / International Development News',
#  'devp': 'Canadian Catholic Organization for Development and Peace',
#  'dhakatribune': 'DT / Dhaka Tribune',
#  'dialogo-americas': 'dialogo-americas',
#  'diariodelnorte': 'Diario del Norte',
#  'diariodelosandes': 'El Diario De Los Andes',
#  'diariodelsur': 'Diario del Sur',
#  'diarioeltiempo': 'diarioeltiempo / Diario el tiempo',
#  'diarioelvistazo': 'Diario El Vistazo',
#  'diariolalibertad': 'diariolalibertad',
#  'diariolaregion': 'La Region El Diario de Miranda',
#  'diariolasamericas': 'Diario Las americas',
#  'diariolibre': 'Diario Libre',
#  'digitalcongo': 'digitalcongo',
#  'dinero': 'Dinero',
#  'diplomatie': "MEAE (France) / Ministère de l'Europe et des Affaires étrangères (France)",
#  'directrelief': 'Direct Relief International',
#  'dnp': 'Government of Colombia',
#  'doctorswithoutborders': 'DWB / Doctors Without borders',
#  'dotnews': 'Dot News',
#  'downtoearth': 'downtoearth',
#  'dropbox': 'OCHA / United Nations Office for the Coordination of Humanitarian Affairs',
#  'dt': 'DT / Dirección del Trabajo, Chile',
#  'duvarenglish': 'duvarenglish',
#  'dw': 'DW / Deutsche Welle',
#  'eacnur': 'www.acnur.org / ACNUR',
#  'ec': 'UNDP / United Nations Development Programme',
#  'ecdc': 'EEAS / europa',
#  'economictimes': 'economictimes',
#  'economist': 'EIU / The Economist Intelligence Unit',
#  'ecre': 'ECRE / European Council on Refugees and Exiles',
#  'ecronicon': 'ecronicon',
#  'ecupunto': 'ecupunto',
#  'edm': 'MMC / Mixed Migration Centre',
#  'edu': 'uniandes',
#  'educationcannotwait': 'ECW / EDUCATION CANNOT WAIT',
#  'efe': 'Agencia EFE',
#  'efectococuyo': 'Efecto Cocuyo',
#  'egyptindependent': 'egyptindependent',
#  'ei-ie': 'EI / Education International',
#  'eje21': 'eje21',
#  'el-carabobeno': 'el carabobeño',
#  'elanrdc': 'elanrdc',
#  'elceo': 'El Ceo',
#  'elcolombiano': 'El Colombiano',
#  'elcomercio': 'El Comercio',
#  'eldestapeweb': 'El Destape Web',
#  'eldiario': 'El Diario',
#  'election-net': 'election-net',
#  'elespectador': 'El Espectador',
#  'elfrente': 'El Frente',
#  'elheraldo': 'El Heraldo',
#  'elimpulso': 'El Impulso.Com',
#  'elinformador': 'El Informador',
#  'elintranews': 'elintranews',
#  'elmercurio': 'ElMercurioOnline',
#  'elmostrador': 'elmostrador / El Mostrador',
#  'elnacional': 'El Nacional',
#  'elnuevosiglo': 'El Nuevo Siglo',
#  'elorientaldemonagas': 'El Oriental de Monogas',
#  'elpais': 'El Pais',
#  'elpaisvallenato': 'El País Vallenato',
#  'elperiodico': 'El Periódico',
#  'elperiodiquito': 'Elperiodiquito / El periodiquito',
#  'elsalvador': 'ONU El Salvador / Naciones Unidas El Salvador',
#  'elsiglo': 'Elsiglo / El siglo',
#  'elsolweb': 'Periódico El Sol',
#  'eltelegrafo': 'El Telégrafo',
#  'eltiempo': 'diarioeltiempo / Diario el tiempo',
#  'eltribuno': 'El Tribuno',
#  'eluniversal': 'El Universal',
#  'eluniverso': 'El Universo',
#  'elvenezolanocolombia': 'elvenezolanocolombia',
#  'emol': 'Emol',
#  'emro': 'WHO / World Health Organization',
#  'enabbaladi': 'enabbaladi',
#  'ennonline': 'ennonline',
#  'environews-rdc': 'environews-rdc',
#  'etcluster': 'ETC / Emergency Telecommunications Cluster',
#  'euro': 'WHO / World Health Organization',
#  'eurodad': 'Eurodad',
#  'europa': 'EC / European Commission',
#  'europapress': array(['Europa Press', 'www.acnur.org / ACNUR'], dtype=object),
#  'evtvmiami': 'El Diario De Los Andes / EV TVmiami',
#  'exposure': 'exposure',
#  'expreso': 'El Expreso',
#  'extra': 'Extranjeria Chile / Departamento de Extranjería y Migración Chile',
#  'faapa': 'faapa',
#  'facebook': 'AANES / Autonomous Authority of North and East Syria',
#  'fao': 'FAO / Food and Agriculture Organization of the United Nations',
#  'fasic': 'FASIC / FUNDACIÓN DE AYUDA SOCIAL DE LAS IGLESIAS CRISTIANAS',
#  'faso-actu': 'faso-actu',
#  'fasoamazone': 'fasoamazone',
#  'fasozine': 'fasozine',
#  'fedesarrollo': 'Fedesarrollo / Fundación para la Educación Superior y el Desarrollo',
#  'fena': 'fena',
#  'fes': 'FES / Friedrich Ebert Stiftung',
#  'fews': 'FEWS NET / Famine Early Warning System Network',
#  'filesusr': 'Caribe Afirmativo',
#  'finances': "MEF / Ministère de l'Economie, des Finances et du Développement",
#  'financialafrik': 'financialafrik',
#  'floodresilience': 'floodresilience',
#  'fm/ar/index': 'Sham FM',
#  'focoeconomico': 'focoeconomico',
#  'fondationpierrefabre': 'Fondation Pierre Fabre',
#  'foodforthepoor': 'FFP / Food for the Poor',
#  'foodtank': 'Food Tank: The Think Tank For Food',
#  'forbes': 'Forbes',
#  'foreignpolicy': 'foreignpolicy / Foreign Policy',
#  'forumdesas': 'forumdesas',
#  'fragomen': 'fragomen',
#  'france24': 'France24',
#  'francebleu': 'francebleu',
#  'francetvinfo': 'francetvinfo',
#  'fronteraysociedad': 'Fronteras y Sociedad',
#  'fscluster': 'fscluster',
#  'fsnau': 'FSNAU / Food Analysis and Nutrition Analysis Unit - Somalia',
#  'funcionpublica': 'Government of Colombia',
#  'fundacionamigosdemonkole': 'fundacionamigosdemonkole',
#  'gage': 'ODI / Overseas Development Institute',
#  'garda': 'Garda World',
#  'gestion': 'SONAGESS / Société Nationale de Gestion du Stock de Sécurité Alimentaire Système d’Information sur les Marchés Agricoles',
#  'gestiondelriesgo': 'UNGRD / Unidad Nacional para la Gestión del Riesgo de Desastres',
#  'giga-hamburg': 'GIGA Focus',
#  'globalcitizen': 'globalcitizen',
#  'globaldetentionproject': 'GDP / Global Detention Project',
#  'globalhungerindex': 'globalhungerindex',
#  'globalnews': 'globalnews / Global News',
#  'globalpartnership': 'GPE / Global Partnership for Education',
#  'globalprotectioncluster': 'GPC / Global Protection Cluster',
#  'globalriskinsights': 'globalriskinsights',
#  'globalvoices': 'Global Voices',
#  'gob': 'TNH / The New Humanitarian',
#  'godocs': 'WFP / United Nations World Food Programme',
#  'google': 'UNCT Bangladesh / United Nations Country Team in Bangladesh',
#  'googleusercontent': 'The Washington Post Company',
#  'gouv': 'Ministère de la Santé (RDC) / Ministère de la Sante République Démocratique du Congo',
#  'gouvernement': 'Govt. Burkina Faso / Government of Burkina Faso',
#  'gov': 'Migración Colombia',
#  'grassrootsonline': 'grassrootsonline',
#  'gsma': 'GSMA',
#  'guardian': 'Mail & Guardian / Mail and Guardian',
#  'h13n': 'H13N / Hora 13 Noticias',
#  'habarirdc': 'habarirdc',
#  'hayat': 'Al Hayat Media Center',
#  'hchr': 'OHCHR / United Nations Office of the High Commissioner for Human Rights',
#  'hea-sahel': 'HEA Sahel / Household Economy Approach Sahel',
#  'headtopics': 'headtopics',
#  'hklaw': 'Hklaw',
#  'hn/aldia/15-al-d%C3%ADa/oim-y-acnur-lanzan-campana-para-evitar-discriminacion-de-migrantes-durante-pandemia': 'Proceso Digital',
#  'hoy': 'Hoy Digital',
#  'hoydiariodelmagdalena': 'Hoy Diario de Magdalena',
#  'hrw': 'HRW / Human Rights Watch',
#  'humanitariangrandchallenge': 'Humanitarian Grand Challenge',
#  'humanitarianoutcomes': 'Humanitarian Outcomes',
#  'humanitarianresponse': 'HR / Humanitarian Response',
#  'humdata': 'humdata',
#  'humvenezuela': 'Humvenezuela',
#  'hurriyetdailynews': 'hurriyetdailynews',
#  'iagua': 'iagua',
#  'icrc': 'ICRC / International Committee of the Red Cross',
#  'ifc': 'IFC / International Finance Cooperation',
#  'ifpri': 'IFPRI / International Food Policy Research Institute',
#  'ifrc': 'IFRC / Intertional Federation of Red Cross',
#  'ilo': 'ILO / International Labour Organization',
#  'imf': 'IMF / International Monetary Fund',
#  'immap': 'iMMAP / Information Management and Mine Action Programs',
#  'impact-repository': 'impact-repository',
#  'indepaz': 'INDEPAZ / Instituto de estudios para el desarrollo y la paz',
#  'independent': 'The Independent',
#  'index': 'index',
#  'inei': 'PHIVOLCS / Philippine Institute of Volcanology and Seismology',
#  'infobae': 'Infobae',
#  'infobascongo': 'infobascongo',
#  'infocongo': 'infocongo',
#  'infomigrants': 'infomigrants',
#  'infomigration': 'infomigracion',
#  'informe21': 'Informe21.Com',
#  'infosegura': 'InfoSegura',
#  'infosplus': 'infosplus',
#  'infowakat': 'infowakat',
#  'ins': 'Instituto Nacional de Salud',
#  'ins-rdc': 'INS (RDC) / Institut National de la Statistique République Démocratique du Congo',
#  'insd': 'INSD / Institut National de la Statistique et de la Démographie Burkina Faso',
#  'insightcrime': 'Insightcrime',
#  'interkinois': 'interkinois',
#  'internal-displacement': 'internal-displacement',
#  'internationalmedicalcorps': 'IMC / International Medical Corps',
#  'interpeace': 'Interpeace',
#  'intersos': 'INTERSOS',
#  'iom': 'IOM / International Organization for Migration',
#  'ipcinfo': 'ipcinfo',
#  'ipsnoticias': 'IPS / Inter Press Service News Agency',
#  'issafrica': 'issafrica',
#  'ius360': 'iustel',
#  'iwacu-burundi': 'iwacu-burundi',
#  'jamanetwork': 'Jama Network',
#  'jesuitas': 'JRS / Seervicio jesuita a refugiados',
#  'jeuneafrique': 'Jeune Afrique',
#  'jhu': 'Johns Hopkins Univ. / Johns Hopkins University',
#  'jrc': 'EEAS / europa',
#  'jrs': 'JRS / Jesuit Refugee Service',
#  'kassioun': 'Kassioun',
#  'kienyke': 'kienyke',
#  'ktpress': 'ktpress',
#  'la-croix': 'la-croix',
#  'laborpresse': 'laborpresse',
#  'lacuarta': 'La Cuarta',
#  'lafm': 'La fm',
#  'lahora': 'La Hora',
#  'lalibre': 'lalibre',
#  'lanacion': 'La Nación',
#  'lanacionweb': 'Diario La Nacion',
#  'laopinion': 'laopinion',
#  'lapatria': 'La Patria',
#  'laprensalara': 'Diario De Lara La Prensa',
#  'laprosperite': 'laprosperite',
#  'larazon': 'La Razón',
#  'larepublica': 'La RepublicaLa / La Republica',
#  'las2orillas': 'las2orillas',
#  'lasillavacia': 'lasillavacia',
#  'lasnoticiasdecojedes': 'Las Noticias de Cojedes',
#  'latercera': 'La Tercera',
#  'latinamerica': 'UNDP / United Nations Development Programme',
#  'latribuna': 'latribuna',
#  'latribune': 'La Tribune Afrique',
#  'lavanguardia': 'la vanguardia',
#  'laverdad': 'La Verdad',
#  'lavozdefalcon': 'lavozdefalcon',
#  'leadership': 'ALA / African Leadership Academy',
#  'lefaso': 'Le Faso',
#  'lefigaro': 'lefigaro',
#  'legit': 'Legit',
#  'leglobal': 'leglobal',
#  'lemonde': 'Le Monde',
#  'lepoint': 'LePoint',
#  'lesechos': 'LesEchos',
#  'letemps': 'Le Temps',
#  'libyaherald': 'libyaherald',
#  'libyanexpress': 'LE / Libyan Express',
#  'libyaobserver': 'LO / The Libya Observer',
#  'linterview': 'linterview',
#  'llanera': 'Llanera',
#  'logcluster': 'Logcluster / Logistics Cluster',
#  'losandes': 'Los Andes',
#  'lse': 'LSE / London School of Economics and Political Science',
#  'lwr': 'RW / United Nations Office for the Coordination of Humanitarian Affairs - ReliefWeb',
#  'magazine24': 'Magazine24',
#  'mailchi': 'mailchi',
#  'mapaction': 'MapAction',
#  'matininfos': 'matininfos',
#  'mcusercontent': 'UNDP / United Nations Development Programme',
#  'mdzol': 'MDZ Diario de Mendoza',
#  'medglobal': 'MedGlobal',
#  'mediacongo': 'Media Congo',
#  'medium': 'OCHA / United Nations Office for the Coordination of Humanitarian Affairs',
#  'medrxiv': 'MedRxiv',
#  'meganoticias': 'Meganoticias',
#  'mei': 'MEI / Middle East Institute',
#  'menafn': 'menafn',
#  'mercycorps': 'mercycorps',
#  'mesrsi': 'mesrsi',
#  'middleeasteye': 'MEE / Middle East Eye',
#  'middleeastmonitor': 'middleeastmonitor',
#  'migracioncolombia': 'migracioncolombia',
#  'migraciones': 'OIM / ORGANIZACION INTERNACIONAL PARA LAS MIGRACIONES',
#  'migrationdataportal': 'Migration Data Portal',
#  'migravenezuela': 'Migravenezuela / Proyecto Migración Venezuela',
#  'milenio': 'MILENIO.COM',
#  'minambiente': 'Government of Colombia',
#  'mineducacion': array(['Government of Colombia', 'Ministerio de Educación'], dtype=object),
#  'minsalud': 'MinSalud / Ministerio de Salud y Protección Social',
#  'mintic': 'Government of Colombia',
#  'mintrabajo': 'Ministerio de Trabajo',
#  'misionescuatro': 'Misiones 4 / Misiones Cuatro',
#  'mixedmigration': 'MMC / Mixed Migration Centre',
#  'mkbco': 'INS (RDC) / Institut National de la Statistique République Démocratique du Congo',
#  'moderndiplomacy': 'Modern Diplomacy',
#  'mofaic': 'mofaic',
#  'monaco-tribune': 'monaco-tribune',
#  'mprnews': 'mprnews',
#  'msf': 'MSF / Médecins Sans Frontières',
#  'msf-azg': 'MSF / Médecins Sans Frontières',
#  'msn': 'FEWSN / Famine Early Warning Systems Network',
#  'n1info': 'n1info',
#  'nacion': 'La Nación',
#  'nairametrics': 'nairametrics',
#  'nbcnews': 'NBC News',
#  'ncbi': 'IHI / Imani House, Inc.',
#  'ncdc': 'NCDC / Nigeria Center for Disease Control',
#  'neoafricanews': 'neoafricanews',
#  'newlinesinstitute': 'New Lines Institute for Strategy and Policy',
#  'newlinesmag': 'New Lines Magazine',
#  'news': 'Tishreen news',
#  'newstatesman': 'newstatesman',
#  'newsweaver': 'newsweaver',
#  'nextierspd': 'Nextier SPD',
#  'nigerianeye': 'nigerianeye',
#  'nkafu': 'nkafu',
#  'nordeatrade': 'nordeatrade',
#  'noticialdia': 'noticialdia',
#  'noticias-tunja': 'noticias-tunja',
#  'noticiascurazao': 'Noticias curazao',
#  'noticierodigital': 'Noticiero Digital',
#  'notimerica': 'Central European Time / Notimerica',
#  'notitotal': 'Notitotal',
#  'npasyria': 'npasyria / North Press Agency Syria',
#  'nrc': 'NRC / Norwegian Refugee Council',
#  'ntn24': 'ntn24',
#  'nytimes': 'NY Times / The New York Times',
#  'oas': 'OAS / OEA / Organization of American States',
#  'observador': 'OVM / Observatorio Venezolano de Migración',
#  'observatoriofeminicidioscolombia': 'OFC / Observatorio Feminicidios Colombia',
#  'odi': 'ODI / Overseas Development Institute',
#  'odihpn': 'ODI - HPN / ODI - Humanitarian Practice Network',
#  'oecd': 'OECD / Organisation for Economic Co-operation and Development',
#  'oecd-ilibrary': array(['OECD / Organisation for Economic Co-operation and Development',
#         'oecd-ilibrary'], dtype=object),
#  'ohchr': 'OHCHR / United Nations Office of the High Commissioner for Human Rights',
#  'ojo-publico': 'Ojo Público',
#  'omrandirasat': 'omrandirasat / Omran Center for Strategic Studies',
#  'opendatadrc': 'opendatadrc',
#  'orfonline': 'orfonline',
#  'org': array(['Interactuar', 'NRC / Norwegian Refugee Council'], dtype=object),
#  'ouaga24': 'ouaga24',
#  'ouestaf': 'Ouestaf',
#  'oup': 'Oxford Academic Journals',
#  'oxfam': 'Oxfam GB / Oxfam Great Britain',
#  'paho': 'PAHO / Pan American Health Organization',
#  'panampost': 'panampost',
#  'panorama': 'Panorama',
#  'parismatch': 'parismatch',
#  'pbs': 'PBS / Public Broadcasting Service',
#  'peaceau': 'African Union Peace and Security',
#  'peacenews': 'Peace News',
#  'perfil': 'Perfil',
#  'periodicolaguajira': 'La Guajira',
#  'periodismopublico': 'Periodismo Público',
#  'peru21': 'Peru21 / Peru 21',
#  'phr': 'PHR / Physicians for Human Rights',
#  'plos': 'PLOS / Public Library of Science',
#  'politico': 'Politico',
#  'portafolio': 'Portafolio',
#  'pourelle': 'pourelle',
#  'premiumtimesng': 'premiumtimesng',
#  'prensalibre': 'prensalibre',
#  'presidencia': 'presidencia',
#  'presidenciave': 'presidencia',
#  'preventepidemics': 'PERC / Partnership for Evidence-Based Response to COVID-19',
#  'primature': 'Primature de la Republique Democratique du Congo',
#  'primerinforme': 'Primer Informe',
#  'primicia': 'Primicia',
#  'publimetro': 'Publimetro',
#  'pulse': 'Pulse',
#  'pulzo': 'Pulzo',
#  'punchng': 'Punchng / Punch Nigeria',
#  'quepasaenvenezuela': 'Qué Pasa en Venezuela',
#  'r4v': 'R4V / Response For Venezuleans',
#  'radiofeyalegrianoticias': 'radiofeyalegrianoticias',
#  'radiomilawoe': 'Radio Milawoe',
#  'radiomundial': 'radiomundial',
#  'radionacional': 'Radio Nacional De Colombia',
#  'radiookapi': 'Radio Okapi',
#  'radiosantafe': 'Radio Santa Fé',
#  'razonpublica': 'Razón Pública',
#  'rcnradio': 'CRC NA / Christian Reformed Church in North America',
#  'rdccovidbusinesssurvey': 'rdccovidbusinesssurvey',
#  'reachresourcecentre': 'reachresourcecentre',
#  'realinstitutoelcano': 'Real Instituto Elcano Royal Institute',
#  'redcross': 'ICRC / International Committee of the Red Cross',
#  'redhum': 'RHN / Red Humanitaria Nacional',
#  'redmas': 'RedMas',
#  'refugeesinternational': 'RI / Refugees International',
#  'reporteconfidencial': 'Reporte Confidencial',
#  'reportur': 'Reportur.co',
#  'republica': 'República de las Ideas',
#  'rescue': 'IRC / International Rescue Committee',
#  'researchgate': 'Researchgate / Research Gate',
#  'reuters': 'Reuters',
#  'revistaentornos': 'Revista Entornos',
#  'rferl': 'rferl',
#  'rfi': 'RFI / Radio France Internationale',
#  'ripplesnigeria': 'ripplesnigeria',
#  'rojavainformationcenter': 'rojavainformationcenter',
#  'rsf': 'RSF / Reporters Sans Frontières',
#  'rtbf': 'RTBF / Radio Télévision Belge Francophone',
#  'rtvbn': 'rtvbn',
#  'runrun': 'Runrun',
#  's3': 'amazonaws',
#  'sabcnews': 'sabcnews',
#  'saharareporters': 'saharareporters',
#  'salaamgateway': 'salaamgateway',
#  'saludcapital': 'Government of Colombia',
#  'sams-usa': 'Syrian American Medical Society Foundation',
#  'sana': 'SANA / Syrian Arab News Agency',
#  'sante': 'Ministère de la Santé (RDC) / Ministère de la Sante République Démocratique du Congo',
#  'santetropicale': 'santetropicale',
#  'sarajevotimes': 'sarajevotimes',
#  'savethechildren': 'SCI / save the children international',
#  'scidev': 'scidev',
#  'sciencedirect': 'Science Direct',
#  'scooprdc': 'scooprdc',
#  'securitycouncilreport': 'securitycouncilreport',
#  'sela': 'SELA / Sistema Económico Latinoamericano y del Caribe',
#  'semana': 'Semana',
#  'sfcg': 'SFCG / Search for Common Ground',
#  'sham': 'Sham FM',
#  'sheltercluster': 'Shelter Cluster',
#  'shinyapps': 'IMPACT Initiatives',
#  'sida': 'Sida / Swedish International Development Cooperation Agency',
#  'sidwaya': 'Sidwaya',
#  'sig': 'SIG / Government Information Service',
#  'sismamujer': 'Corporación Sisma Mujer',
#  'sky': 'sky',
#  'slobodnaevropa': 'slobodnaevropa',
#  'sn4hr': 'SNHR / Syrian Network for Human Rights',
#  'societegenerale': 'societegenerale',
#  'solidarites': 'Solidarités International',
#  'somosiberoamerica': 'Somos Iberoamérica',
#  'sosmediasburundi': 'sosmediasburundi',
#  'soychile': 'Soychile / Soy Chile',
#  'sputniknews': 'Sputnik Mundo',
#  'squarespace': 'squarespace',
#  'stereo100': 'stereo100',
#  'substack': 'Syria in Context',
#  'sunnewsonline': 'sunnewsonline',
#  'sunriserdc': 'sunriserdc',
#  'supernoticiasdelvalle': 'supernoticiasdelvalle',
#  'swarajyamag': 'Swarajya',
#  'swissinfo': 'swissinfo',
#  'syria': 'Syria TV',
#  'syriacpress': 'SyriacPress / Syriac Press',
#  'syriadirect': 'Syria Direct',
#  'syriahealthnetwork': 'Syria Health Network / Syria Public Health Network',
#  'syriahr': 'Syrian Observatory for Human Rights',
#  'syrianobserver': 'syrianobserver',
#  'syriatimes': 'Syria Times',
#  'syriauntold': 'Syria Untold',
#  'tbdiah': 'tbdiah',
#  'tchadinfos': 'tchadinfos',
#  'telemedellin': 'TeleMedellín',
#  'telemundo': 'Telemundo',
#  'telesurtv': 'TeleSur / Tele Sur',
#  'thawra': 'Al-Thawra',
#  'the-monitor': 'the-monitor',
#  'thecable': 'thecable',
#  'thecommonwealth': 'The Commonwealth',
#  'theconversation': 'theconversation',
#  'thedailystar': 'DT / Dhaka Tribune',
#  'thedefensepost': 'thedefensepost',
#  'theeagleonline': 'theeagleonline',
#  'theeastafrican': 'theeastafrican',
#  'theguardian': 'theguardian',
#  'thenationalnews': 'The National News',
#  'thenationonlineng': 'thenationonlineng',
#  'thenewhumanitarian': 'TNH / The New Humanitarian',
#  'thenextweb': 'TNW / The Next Web',
#  'thisdaylive': 'thisdaylive',
#  'today': 'Today Online',
#  'touteinfo': 'Toute Info',
#  'translate': 'salonsyria / Salon Syria',
#  'tribune242': 'The Tribune',
#  'tribuneonlineng': 'tribuneonlineng',
#  'trtworld': 'trtworld',
#  'trust': 'Reuters',
#  'tubarco': 'Tubarco / Tu Barco',
#  'turkishminute': 'turkishminute',
#  'tv5monde': 'TV5MONDE',
#  'twitter': 'Twitter',
#  'ub': 'uni-muenchen',
#  'udea': 'Universidad de Antioquia',
#  'ultimasnoticias': 'DiarioUltimasNoticias / Ultimas Noticias',
#  'un': 'United Nations',
#  'unb': 'UNB / United News of Bangladesh',
#  'undp': 'UNDP / United Nations Development Programme',
#  'unesco': 'UNESCO / United Nations Educational, Scientific and Cultural Organization',
#  'unescwa': 'ESCWA / United Nations Economic and Social Commission for Western Asia',
#  'unfpa': 'UNFPA / United Nations Population Fund',
#  'unhcr': 'UNHCR / United Nations High Commissioner for Refugees',
#  'uniandes': 'uniandes',
#  'unicef': "UNICEF / United Nations Children's Fund",
#  'unicefusa': 'unicefusa',
#  'unidadvictimas': 'unidadvictimas',
#  'unidiversidad': 'Unidiversidad',
#  'uniminutoradio': 'Un Minuto Radio',
#  'unitar': 'UNITAR / United Nations Institute for Training and Research',
#  'unmissions': 'unmissions',
#  'unocha': 'UNOCHA / United Nations Office for the Coordination of Humanitarian Affairs',
#  'unops': 'UNOPS / United Nations Office for Project Services',
#  'unrwa': 'UNRWA / United Nations Relief and Works Agency for Palestine Refugees in the Near East',
#  'unwomen': 'UN Women / United Nations Entity for Gender Equality and the Empowerment of Women',
#  'usaid': 'USAID / United States Agency for International Development',
#  'usembassy': 'usembassy',
#  'usrfiles': 'ProBogotá',
#  'vanguardia': 'Vanguardia',
#  'vanguardngr': 'vanguardngr',
#  'vaticannews': 'vaticannews',
#  'vecernji': 'vecernji',
#  'venezuelaaldia': 'venezuela al dia',
#  'versionfinal': 'Version Final',
#  'vicepresidencia': 'GOBIERNOBOLIVARIANODE VENEZUELA / GOBIERNO BOLIVARIANO DE VENEZUELA',
#  'vivafrik': 'vivafrik',
#  'voaafrique': 'voaafrique',
#  'voanews': 'voanews',
#  'voanoticias': 'voa noticias.com',
#  'voces365': 'Voces 365',
#  'wakatsera': 'wakatsera',
#  'washcluster': 'WC / Wash Cluster',
#  'washdata': 'WHO / World Health Organization',
#  'washingtonpost': 'The Washington Post Company',
#  'weforum': 'WEF / World Economic Forum',
#  'wfp': 'WFP / United Nations World Food Programme',
#  'who': 'WHO / World Health Organization',
#  'wixstatic': 'Servicio Jesuita a Migrantes',
#  'wola': 'WOLA / Washington Office on Latin America',
#  'world-grain': 'world-grain / World Grain',
#  'worldbank': 'WB / World Bank Group',
#  'worldcement': 'worldcement',
#  'wradio': 'W Radio',
#  'wsscc': 'WSSCC',
#  'wvi': 'wvi',
#  'xinhuanet': 'Xinhuanet',
#  'yaleclimateconnections': 'yaleclimateconnections',
#  'yenisafak': 'Yeni Safak',
#  'zamanalwsl': 'Zaman Al Wasl',
#  'zenuradio': 'Zenu Radio',
#  'zonacero': 'zonacero',
#  'zoodomail': 'zoodomail',
#  'zoom-eco': 'zoom-eco'}

# %% [markdown]
# ## 2) NON website data
# * `source_raw`: data imported from taggers
# * `postprocessed_name`: data imported and preprocessed from `organisations` dataframe
#
# * Merge these two columns to create one column that is best for

# %%
non_website_data = merged_reliability[merged_reliability.source_type!='website']\
                    .drop(columns=['lead_group_id', 'source_type'])\

# %%
non_website_data.head()
# Out:
#      entry_id         tag_value             source_raw website author_raw  \
# 255   33155.0  Usually reliable  Philippines Red Cross     NaN        NaN
# 256   33156.0  Usually reliable  Philippines Red Cross     NaN        NaN
# 257   33150.0  Usually reliable  Philippines Red Cross     NaN        NaN
# 258   33141.0  Usually reliable  Philippines Red Cross     NaN        NaN
# 259   33153.0  Usually reliable  Philippines Red Cross     NaN        NaN
#
#     postprocessed_name
# 255                NaN
# 256                NaN
# 257                NaN
# 258                NaN
# 259                NaN

# %%
def strip_string(x:str)->str:
    return ''.join(x.split(' ')).upper()

# %%
def get_names(x:pd.Series)->str:
    """
    merge postprocessed_name and source_raw
    """
    post_name = x.postprocessed_name
    raw_name = x.source_raw
    if pd.isna(raw_name) and pd.isna(post_name):
        return 'UNKNOWN'
    
    if pd.isna(raw_name):
        return post_name
    
    if pd.isna(post_name):
        return raw_name
    
    return post_name

# %%
non_website_data['postprocessed_name'] =\
    non_website_data.apply(lambda x: get_names(x),axis=1)

# %%
non_website_data.head(2)
# Out:
#      entry_id         tag_value             source_raw website author_raw  \
# 255   33155.0  Usually reliable  Philippines Red Cross     NaN        NaN
# 256   33156.0  Usually reliable  Philippines Red Cross     NaN        NaN
#
#         postprocessed_name
# 255  Philippines Red Cross
# 256  Philippines Red Cross

# %% [markdown]
# **Remaining work**
# * Cleaning on `postprocessed_name` for `website_data` and `non_website_data`
# * concatenate `website_data` and `non_website_data` on the `postprocessed_name`
# * Generating dict $\{postprocessed_-name: reliability\}$

# %%
whole_df = pd.concat([website_data[['postprocessed_name', 'tag_value']],
                      non_website_data[['postprocessed_name', 'tag_value']]])

# %%
name_to_reliability_dict = dict(zip(whole_df.postprocessed_name, whole_df.tag_value))

# %%
len(name_to_reliability_dict)
# Out:
# 999
